# %% [markdown]
# *********************************************
# *********************************************
# # Description of sample data
# ##  Created by Clarkson university Airlab team
#
# *********************************************
# *********************************************
#
#
#
# ### If you have any questions or concerns, please contact : sdhaniya@clarkson.edu (Suresh Dhaniyala)

# %%
# 2019/07/14 N.Kuerbanjiang
# import packages  
##############################################

# %matplotlib inline
# %config InlineBackend.figure_format='svg'


import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as mticker
import matplotlib.dates as mdates
sns.set()
from datetime import datetime, timedelta
from scipy.signal import savgol_filter 
plt.style.use('seaborn-white')

# %% [markdown]
# # All data will send to Clarkson University's lab sever from each sensor
# # [ "I am  the link that can send you to server "](http://128.153.15.208/phpmyadmin/)
#
# ## Username: cuairlab
# ## Password: cuairlab2019
#
#
# ###  All data will be save in a database called : "particle"
# ### Different sensors data go to different table

# %% [markdown]
# ********************************************************

# %% [markdown]
# # Plantower sensor
#
# ## In plantower sensor data, there will be 13 columns:
#  Date, row_id,PM1.0,PM2.5,PM10,PN0.3,PN0.5,PN1.0,PN2.5,PN5.0,PN10,Temperature,Relative humidity

# %%
df1=pd.read_csv('/Users/nuera/Desktop/argon test4/argon1.csv')
df1.columns = ["Date","id",'pm1.0',"pm2.5","pm10","0.3um","0.5um","1.0um","2.5um","5.0um","10um","temp","humidity"]
df1['time'] = pd.to_datetime(df1['Date'])
df1.index=df1['time']
df1=df1['2019-07-14 16:54:01':'2019-07-14 21:41:00']

# %% [markdown]
# #### Units for PM1.0 : $ug/m^3$
# #### Units for PM2.5 : $ug/m^3$
# #### Units for PM10 : $ug/m^3$
# #### Units for PN0.3 : $particles / 0.1L $
# #### Units for PN0.5 : $particles / 0.1L $
# #### Units for PN1.0 : $particles / 0.1L $
# #### Units for PN2.5 : $particles / 0.1L $
# #### Units for PN5.0 : $particles / 0.1L $
# #### Units for PN10 : $particles / 0.1L $
# #### Units for Temp: C degree
# #### Units for RH : %

# %% [markdown]
# # Example plot of plantower PM2.5:

# %%
df1['pm2.5']=savgol_filter(df1['pm2.5'], 31, 1)

fig, ax1 = plt.subplots()
fig.set_size_inches(11.7, 8.27)

ax1.grid(False)

lns2=ax1.plot(df1['time'],df1['pm2.5'], linewidth=2,label='Plantower PM2.5 data')


lns = lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc='best',fontsize=15,markerscale=4)


ax1.set_xlabel('$Time$ $Line$',fontsize=16,color='k',labelpad=13)
ax1.set_ylabel('$PM2.5$ ($ug/m^3$)',color='k',fontsize=16,labelpad=13)


ax1.tick_params(axis = 'both', which = 'major', labelsize = 15)

for label in ax1.xaxis.get_ticklabels():
       label.set_rotation(0)
ax1.xaxis.set_major_locator(mticker.MaxNLocator(7))


ax1.fill_between(df1['time'], df1['pm2.5'],color='magenta',alpha=.1)
myFmt = mdates.DateFormatter('%H:%M')
ax1.xaxis.set_major_formatter(myFmt)

# %% [markdown]
# # Honeywell sensor
#
# ## In honeywell sensor data, there will be 6 columns:
#  Date, row_id,PM2.5,PM10,Temperature,Relative humidity

# %%
df2=pd.read_csv('/Users/nuera/Desktop/argon test4/argon9.csv')
df2.columns = ["Date","id",'pm2.5',"pm10","temp","humidity"]
df2['time'] = pd.to_datetime(df2['Date'])
df2.index=df2['time']
df2=df2['2019-07-14 16:54:01':'2019-07-14 21:41:00']

# %% [markdown]
# #### Units for PM2.5 : $ug/m^3$
# #### Units for PM10 : $ug/m^3$
# #### Units for Temp: C degree
# #### Units for RH : %

# %% [markdown]
# # Example plot of honeywell PM2.5:

# %%
df2['pm2.5']=savgol_filter(df2['pm2.5'], 31, 1)

fig, ax1 = plt.subplots()
fig.set_size_inches(11.7, 8.27)

ax1.grid(False)

lns2=ax1.plot(df2['time'],df2['pm2.5'], linewidth=2,label='Honeywell PM2.5 data')


lns = lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc='best',fontsize=15,markerscale=4)


ax1.set_xlabel('$Time$ $Line$',fontsize=16,color='k',labelpad=13)
ax1.set_ylabel('$PM2.5$ ($ug/m^3$)',color='k',fontsize=16,labelpad=13)


ax1.tick_params(axis = 'both', which = 'major', labelsize = 15)

for label in ax1.xaxis.get_ticklabels():
       label.set_rotation(0)
ax1.xaxis.set_major_locator(mticker.MaxNLocator(7))


ax1.fill_between(df2['time'], df2['pm2.5'],color='green',alpha=.1)
myFmt = mdates.DateFormatter('%H:%M')
ax1.xaxis.set_major_formatter(myFmt)

# %% [markdown]
# # Shinyei sensor
#
# ## In Shinyei sensor data, there will be 5 columns:
#  Date, row_id,Low Puls Ratio,Temperature,Relative humidity

# %%
df3=pd.read_csv('/Users/nuera/Desktop/argon test4/argon14.csv')
df3.columns = ["Date","id","shinyei","temp","humidity"]
df3['time'] = pd.to_datetime(df3['Date'])
df3.index=df3['time']
df3=df3['2019-07-14 16:54:01':'2019-07-14 21:41:00']

# %% [markdown]
# # Example plot of Shinyei data:

# %%
df3['shinyei']=savgol_filter(df3['shinyei'], 31, 1)

fig, ax1 = plt.subplots()
fig.set_size_inches(11.7, 8.27)

ax1.grid(False)

lns2=ax1.plot(df3['time'],df3['shinyei'], linewidth=2,label='Shinyei data')


lns = lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc='best',fontsize=15,markerscale=4)


ax1.set_xlabel('$Time$ $Line$',fontsize=16,color='k',labelpad=13)
ax1.set_ylabel('$LPR$ (%)',color='k',fontsize=16,labelpad=13)


ax1.tick_params(axis = 'both', which = 'major', labelsize = 15)

for label in ax1.xaxis.get_ticklabels():
       label.set_rotation(0)
ax1.xaxis.set_major_locator(mticker.MaxNLocator(7))


ax1.fill_between(df3['time'], df3['shinyei'],color='yellow',alpha=.1)
myFmt = mdates.DateFormatter('%H:%M')
ax1.xaxis.set_major_formatter(myFmt)

# %% [markdown]
# # Ipmc (iOT particle monitoring cube)
#
# ## IPMC including plantower and shinyei sensor
#
# ## In IPMC data, there will be 14 columns:
#  Date, row_id,PM1.0,PM2.5,PM10,PN0.3,PN0.5,PN1.0,PN2.5,PN5.0,PN10,shinyei,Temperature,Relative humidity

# %%
df4=pd.read_csv('/Users/nuera/Desktop/New folder/argon26.csv')
df4.columns = ["Date","id",'pm1.0',"pm2.5","pm10","0.3um","0.5um","1.0um","2.5um","5.0um","10um","shinyei","temp","humidity"]
df4['time'] = pd.to_datetime(df4['Date'])
df4.index=df4['time']
df4=df4['2019-07-09 15:00:01':'2019-07-10 08:37:00']

# %% [markdown]
# # Example plot of IPMC data:

# %%
df4['pm2.5']=savgol_filter(df4['pm2.5'], 297, 1)
df4['shinyei']=savgol_filter(df4['shinyei'], 497, 1)

fig, ax1 = plt.subplots()
fig.set_size_inches(11.7, 8.27)
ax2 = ax1.twinx()

ax1.grid(False)

lns1=ax1.plot(df4['time'],df4['pm2.5'], linewidth=2,label='Plantower PM2.5')
lns2=ax2.plot(df4['time'],df4['shinyei'], linewidth=2,color='r',label='Shinyei')



lns = lns1+lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc='best',fontsize=17,markerscale=4)


ax1.set_xlabel('$Time$ $Line$',fontsize=16,color='k',labelpad=13)
ax1.set_ylabel('$PM 2.5$ ($ug/m^3$)',color='k',fontsize=16,labelpad=13)
ax2.set_ylabel('$Shinyei$ ($LPR$)',color='k',fontsize=16,labelpad=13)


ax1.tick_params(axis = 'both', which = 'major', labelsize = 15)

for label in ax1.xaxis.get_ticklabels():
       label.set_rotation(0)
ax1.xaxis.set_major_locator(mticker.MaxNLocator(7))

ax1.fill_between(df4['time'], df4['pm2.5'],color='b',alpha=.1)
ax2.fill_between(df4['time'], df4['shinyei'],color='r',alpha=.1)


myFmt = mdates.DateFormatter('%H:%M')
ax1.xaxis.set_major_formatter(myFmt)

# %%
s1=df4['shinyei'].resample('3Min', how='mean')
p=df4['pm2.5'].resample('3Min', how='mean')


plt.figure(figsize=(10,8))

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)


plt.scatter(p, s1, color= 'k',alpha=0.9,label='Shinyei VS Plantower')


plt.legend( loc='best',fontsize=17)

plt.title("Shinyei VS plantower", fontsize=16)
plt.xlabel('Plantower pm2.5',fontsize=16,color='k',labelpad=13)
plt.ylabel('Shinyei LPR',fontsize=16,color='k',labelpad=13)
# Out:
# C:\Users\nuera\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
#   """Entry point for launching an IPython kernel.
# C:\Users\nuera\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
# Text(0, 0.5, 'Shinyei LPR')
